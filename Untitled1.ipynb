# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname="C:\\Windows\\Fonts\\malgun.ttf").get_name()
plt.rc("font",family=font_name)

mpl.rcParams["axes.unicode_minus"]= False

# %%
train = pd.read_csv('data/train_train_train_train.csv', index_col = [0], encoding = 'euc-kr')

train.tail()
# Out:
#          gu dong  exclusive_use_area  year_of_completion  floor  \
# 742280  강동구  강일동               59.72                2011      9
# 742281  강동구  강일동               59.87                2009     12
# 742282  강동구  강일동               84.74                2009      3
# 742283  강동구  강일동               84.74                2009      9
# 742284  강동구  강일동               84.98                2011      8
#
#         transaction_real_price  hanriver  transaction_year  transaction_month  \
# 742280                   53000         0              2017                 11
# 742281                   53000         0              2017                 11
# 742282                   56500         0              2017                 11
# 742283                   55500         0              2017                 11
# 742284                   63750         0              2017                 11
#
#         transaction_date  ...  pop_dense  poppop  pop_rank  area_rank  \
# 742280                 1  ...      17909  440359        11          8
# 742281                 2  ...      17909  440359        11          8
# 742282                 2  ...      17909  440359        11          8
# 742283                 2  ...      17909  440359        11          8
# 742284                 2  ...      17909  440359        11          8
#
#         floor_area  river_study       var_1  diff_year  rebuilding  river_re
# 742280           0            9  887.474883          6           0         1
# 742281           9            9  885.251378          8           0         1
# 742282           0            9  666.745339          8           0         1
# 742283           0            9  654.944536          8           0         1
# 742284           0            9  750.176512          6           0         1
#
# [5 rows x 37 columns]

# %%
plt.figure(figsize = (20, 7))
# gu_dep = train.sort_values(by = ['dep_shop'], axis = 0, ascending = True)
plt.bar(train['gu'], train['transaction_real_price'], width = 0.7)
# Out:
# <BarContainer object of 742285 artists>
